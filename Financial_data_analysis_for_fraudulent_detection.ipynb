# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.metrics import average_precision_score
from xgboost.sklearn import XGBClassifier
from xgboost import plot_importance, to_graphviz

# %%
data = pd.read_csv('/home/abhishek/projects/Financialdataset/PS_20174392719_1491204439457_log.csv')

# %%
data.head(5)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
data.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
data.isnull().any()
# Out:
# step              False
# type              False
# amount            False
# nameOrig          False
# oldbalanceOrg     False
# newbalanceOrig    False
# nameDest          False
# oldbalanceDest    False
# newbalanceDest    False
# isFraud           False
# isFlaggedFraud    False
# dtype: bool

# %%
data['isFlaggedFraud'].unique()
# Out:
# array([0, 1])

# %%
data['isFraud'].unique()
# Out:
# array([0, 1])

# %%
dataFraud = data[data['isFraud']== 1 ]

# %%
dataFraud.head(10)
# Out:
#       step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2        1  TRANSFER      181.00  C1305486145         181.00             0.0
# 3        1  CASH_OUT      181.00   C840083671         181.00             0.0
# 251      1  TRANSFER     2806.00  C1420196421        2806.00             0.0
# 252      1  CASH_OUT     2806.00  C2101527076        2806.00             0.0
# 680      1  TRANSFER    20128.00   C137533655       20128.00             0.0
# 681      1  CASH_OUT    20128.00  C1118430673       20128.00             0.0
# 724      1  CASH_OUT   416001.33   C749981943           0.00             0.0
# 969      1  TRANSFER  1277212.77  C1334405552     1277212.77             0.0
# 970      1  CASH_OUT  1277212.77   C467632528     1277212.77             0.0
# 1115     1  TRANSFER    35063.63  C1364127192       35063.63             0.0
#
#          nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# ...

# %%
plt.figure(figsize = (10,7))
sns.barplot(data.type.value_counts().values,data.type.value_counts().index)
plt.xlabel("Counts")
plt.ylabel("type")
plt.show()

# %% [raw]
# The above graph shows the most fraudulent medium where fraud occurs in order .

# %%
data[(data['isFraud']== 1) & (data['isFlaggedFraud']==1)]
# Out:
#          step      type       amount     nameOrig  oldbalanceOrg  \
# 2736446   212  TRANSFER   4953893.08   C728984460     4953893.08
# 3247297   250  TRANSFER   1343002.08  C1100582606     1343002.08
# 3760288   279  TRANSFER    536624.41  C1035541766      536624.41
# 5563713   387  TRANSFER   4892193.09   C908544136     4892193.09
# 5996407   425  TRANSFER  10000000.00   C689608084    19585040.37
# 5996409   425  TRANSFER   9585040.37   C452586515    19585040.37
# 6168499   554  TRANSFER   3576297.10   C193696150     3576297.10
# 6205439   586  TRANSFER    353874.22  C1684585475      353874.22
# 6266413   617  TRANSFER   2542664.27   C786455622     2542664.27
# 6281482   646  TRANSFER  10000000.00    C19004745    10399045.08
# 6281484   646  TRANSFER    399045.08   C724693370    10399045.08
# 6296014   671  TRANSFER   3441041.46   C917414431     3441041.46
# 6351225   702  TRANSFER   3171085.59  C1892216157     3171085.59
# ...

# %% [raw]
# 1)The beauty is for tranfers mode ,the system is flagging as fraud
# 2)OLDBALANCEDEST , NEWBALANCEDEST remains 0 .

# %%
data[(data['isFraud']== 1) & (data['isFlaggedFraud']==0)]
# Out:
#          step      type       amount     nameOrig  oldbalanceOrg  \
# 2           1  TRANSFER       181.00  C1305486145         181.00
# 3           1  CASH_OUT       181.00   C840083671         181.00
# 251         1  TRANSFER      2806.00  C1420196421        2806.00
# 252         1  CASH_OUT      2806.00  C2101527076        2806.00
# 680         1  TRANSFER     20128.00   C137533655       20128.00
# 681         1  CASH_OUT     20128.00  C1118430673       20128.00
# 724         1  CASH_OUT    416001.33   C749981943           0.00
# 969         1  TRANSFER   1277212.77  C1334405552     1277212.77
# 970         1  CASH_OUT   1277212.77   C467632528     1277212.77
# 1115        1  TRANSFER     35063.63  C1364127192       35063.63
# 1116        1  CASH_OUT     35063.63  C1635772897       35063.63
# 1869        1  TRANSFER     25071.46   C669700766       25071.46
# 1870        1  CASH_OUT     25071.46  C1275464847       25071.46
# ...

# %% [raw]
# But ultimately for many transfer mode , the system has not been flagged as fraud :(

# %%
y = data['isFraud']

# %%
factors = ['step','type','amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']

# %%
x = data[factors]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
x['type'] = labelencoder.fit_transform(x['type'])
# Out:
# /home/abhishek/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x
# Out:
#          step  type      amount  oldbalanceOrg  newbalanceOrig  \
# 0           1     3     9839.64      170136.00       160296.36
# 1           1     3     1864.28       21249.00        19384.72
# 2           1     4      181.00         181.00            0.00
# 3           1     1      181.00         181.00            0.00
# 4           1     3    11668.14       41554.00        29885.86
# 5           1     3     7817.71       53860.00        46042.29
# 6           1     3     7107.77      183195.00       176087.23
# 7           1     3     7861.64      176087.23       168225.59
# 8           1     3     4024.36        2671.00            0.00
# 9           1     2     5337.77       41720.00        36382.23
# 10          1     2     9644.94        4465.00            0.00
# 11          1     3     3099.97       20771.00        17671.03
# 12          1     3     2560.74        5070.00         2509.26
# 13          1     3    11633.76       10127.00            0.00
# ...

# %%
limit = len(x)

# %%
x.corr()
# Out:
#                     step      type    amount  oldbalanceOrg  newbalanceOrig  \
# step            1.000000  0.006635  0.022373      -0.010058       -0.010299
# type            0.006635  1.000000  0.088419      -0.339760       -0.352758
# amount          0.022373  0.088419  1.000000      -0.002762       -0.007861
# oldbalanceOrg  -0.010058 -0.339760 -0.002762       1.000000        0.998803
# newbalanceOrig -0.010299 -0.352758 -0.007861       0.998803        1.000000
# oldbalanceDest  0.027665 -0.104679  0.294137       0.066243        0.067812
# newbalanceDest  0.025888 -0.059364  0.459304       0.042029        0.041837
#
#                 oldbalanceDest  newbalanceDest
# step                  0.027665        0.025888
# type                 -0.104679       -0.059364
# amount                0.294137        0.459304
# oldbalanceOrg         0.066243        0.042029
# newbalanceOrig        0.067812        0.041837
# oldbalanceDest        1.000000        0.976569
# ...

# %% [markdown]
# (oldbalanceOrg, newbalanceOrig)   (oldbalanceDest,newbalanceDest) are highly correlated

# %%
Xfraud = x.loc[y == 1] # update Xfraud & XnonFraud with cleaned data
XnonFraud = x.loc[y == 0]
                  
correlationNonFraud = XnonFraud.loc[:, x.columns != 'step'].corr()
mask = np.zeros_like(correlationNonFraud)
indices = np.triu_indices_from(correlationNonFraud)
mask[indices] = True

grid_kws = {"width_ratios": (.9, .9, .05), "wspace": 0.2}
f, (ax1, ax2, cbar_ax) = plt.subplots(1, 3, gridspec_kw=grid_kws,figsize = (14, 9))

cmap = sns.diverging_palette(220, 8, as_cmap=True)
ax1 =sns.heatmap(correlationNonFraud, ax = ax1, vmin = -1, vmax = 1,cmap = cmap, square = False, linewidths = 0.5, mask = mask, cbar = False)
ax1.set_xticklabels(ax1.get_xticklabels(), size = 16); 
ax1.set_yticklabels(ax1.get_yticklabels(), size = 16); 
ax1.set_title('Genuine \n transactions', size = 20)

correlationFraud = Xfraud.loc[:, x.columns != 'step'].corr()
ax2 = sns.heatmap(correlationFraud, vmin = -1, vmax = 1, cmap = cmap, ax = ax2, square = False, linewidths = 0.5, mask = mask, yticklabels = False,cbar_ax = cbar_ax, cbar_kws={'orientation': 'vertical','ticks': [-1, -0.5, 0, 0.5, 1]})
ax2.set_xticklabels(ax2.get_xticklabels(), size = 16); 
ax2.set_title('Fraudulent \n transactions', size = 20);

cbar_ax.set_yticklabels(cbar_ax.get_yticklabels(), size = 14);

# %%
from sklearn.model_selection import train_test_split
randomState = 5
trainX, testX, trainY, testY = train_test_split(x, y, test_size = 0.2,random_state = randomState)

# %%
clf = XGBClassifier(max_depth = 3)
probabilities = clf.fit(trainX, trainY).predict_proba(testX)
print('AUPRC = {}'.format(average_precision_score(testY,probabilities[:, 1])))
# Out:
# AUPRC = 0.853731570411

# %%
clf.score(testX,testY)
# Out:
# 0.9844757348387928

# %%
from sklearn.ensemble  import RandomForestClassifier
clf22 = RandomForestClassifier(n_estimators=100, max_depth=3,random_state=0)
clf22.fit(trainX, trainY).predict_proba(testX)

clf22.score(testX,testY)
# Out:
# [0.25826791 0.09767325 0.1355648  0.24228883 0.03611497 0.03706201
#  0.19302822]
# 0.9988275270250305

# %%
print trainX.columns.tolist()
print(clf22.feature_importances_)
# Out:
# ['step', 'type', 'amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']
# [0.25826791 0.09767325 0.1355648  0.24228883 0.03611497 0.03706201
#  0.19302822]

# %% [raw]
# At below we can see the important features as per XGB

# %%
fig = plt.figure(figsize = (14, 9))
ax = fig.add_subplot(111)

colours = plt.cm.Set1(np.linspace(0, 1, 9))

ax = plot_importance(clf, height = 1, color = colours, grid = False,ax = ax);
for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(2)
        
ax.set_xlabel('importance score', size = 16);
ax.set_ylabel('features', size = 16);
ax.set_yticklabels(ax.get_yticklabels(), size = 12);
ax.set_title('Ordering of features by importance to the model learnt', size = 20);

# %% [markdown]
# The important features below as per Random forest

# %%
feat_importances = clf22.feature_importances_
feat_importances 
width = 1/1.5
plt.bar(trainX.columns.tolist(),feat_importances,width)
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# to check tree of XGB

# %%
to_graphviz(clf)

# %% [markdown]
# to check tree of Random forest

# %%
from sklearn.tree import export_graphviz
estimator = clf22.estimators_[6]
export_graphviz(estimator, out_file='tree.dot',rounded = True, proportion = False,precision = 2, filled = True)
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])
from IPython.display import Image
Image(filename = 'tree.png')

# %% [markdown]
# But Both Random forest , XGBoost do well in this data
